# %% [markdown]
# ## <font color=green> Agregação de dados e operações em grupos

# %% [markdown]
# - O pandas oferece uma interface flexível groupby, que permite manipular e resumir conjuntos de dados de forma flexível

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Funcionamento de GroupBy

# %% [markdown]
# - Vamos começar carregando o dataset

# %%
order_leads = pd.read_csv("datasets/order_leads.csv")
sales_team = pd.read_csv("datasets/sales_team.csv")

# %%
df = pd.merge(order_leads,sales_team, on=['Company Id', 'Company Name'])
df = df.rename(columns={'Order Value':'Val', 'Converted': 'Sale'})
df.head()
# Out:
#            Order Id        Company Id            Company Name        Date  \
# 0  HZSXLI1IS9RGABZW  D0AUXPP07H6AVSGD  Melancholy Social-Role  2017-10-13
# 1  582WPS3OW8T6YT0R  D0AUXPP07H6AVSGD  Melancholy Social-Role  2017-09-02
# 2  KRF65MQZBOYG4Y9T  D0AUXPP07H6AVSGD  Melancholy Social-Role  2016-12-21
# 3  N3EDZ5V1WGSWW828  D0AUXPP07H6AVSGD  Melancholy Social-Role  2018-06-03
# 4  QXBC8COXEXGFSPLP  D0AUXPP07H6AVSGD  Melancholy Social-Role  2014-07-26
#
#     Val  Sale       Sales Rep      Sales Rep Id
# 0  6952     0  William Taylor  ZTZA0ZLYZR85PTUJ
# 1  7930     0  William Taylor  ZTZA0ZLYZR85PTUJ
# 2  5538     1  William Taylor  ZTZA0ZLYZR85PTUJ
# 3  1113     0  William Taylor  ZTZA0ZLYZR85PTUJ
# 4  4596     0  William Taylor  ZTZA0ZLYZR85PTUJ

# %% [markdown]
# - Podemos agrupar series

# %%
grouped = df.groupby('Sales Rep')
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# - Chamando a função groups, o objeto retorna uma lista de índices para cada grupo

# %%
grouped.groups
# Out:
# {'Aaron Hendrickson': [25612, 25613, 25614, 25615, 25616, 25617, 25618, 25619, 25620, 25621, 25622, 25623, 25624, 25625, 25626, 25627, 25628, 25629, 25630, 25631, 25632, 25633, 25634, 25635, 25636, 25637, 25638, 25639, 25640, 25641, 25642, 25643, 25644, 25645, 25646, 25647, 25648, 25649, 25650, 25651, 25652, 25653, 25654, 25655, 25656, 25657, 25658, 25659, 25660, 25661, 25662, 25663, 25664, 25665, 25666, 25667, 25668, 25669, 25670, 25671, 25672, 25673, 25674, 25675, 25676, 25677, 25678, 25679, 25680, 25681, 25682, 25683, 25684, 25685, 25686, 25687, 25688, 25689, 25690, 25691, 25692, 25693, 25694, 25695, 25696, 25697, 25698, 25699, 25700, 25701, 25702, 25703, 25704, 25705, 25706, 25707, 25708, 25709, 25710, 25711, ...], 'Adam Sawyer': [67140, 67141, 67142, 67143, 67144, 67145, 67146, 67147, 67148, 67149, 67150, 67151, 67152, 67153, 67154, 67155, 67156, 67157, 67158, 67159, 67160, 67161, 67162, 67163, 67164, 67165, 67166, 67167, 67168, 67169, 67170, 67171, 67172, 67173, 67174, 67175, 6
# ...

# %% [markdown]
# - Chamando a função get_group, nós podemos retornar um subconjunto de dados

# %%
grouped.get_group('Aaron Hendrickson')
# Out:
#                Order Id        Company Id        Company Name        Date  \
# 25612  3BJY12LWBN7D0GJL  CE4544HJOFMONMH2  Follow-Up Boundary  2014-09-04
# 25613  W3HHOSC1H6A1PW37  CE4544HJOFMONMH2  Follow-Up Boundary  2015-09-24
# 25614  G9JKIZO4WD945GBH  CE4544HJOFMONMH2  Follow-Up Boundary  2014-12-06
# 25615  BKIJVKZ7REVN6P8B  CE4544HJOFMONMH2  Follow-Up Boundary  2017-05-07
# 25616  WFHGWR4PAD04A2GJ  CE4544HJOFMONMH2  Follow-Up Boundary  2016-01-20
# ...                 ...               ...                 ...         ...
# 25899  NATK7K3TZUH32BBE  CGDGXAW6GNU6JIEG      Fiftieth Art'S  2015-01-27
# 25900  EGD6IRB0UML62XB0  CGDGXAW6GNU6JIEG      Fiftieth Art'S  2018-11-04
# 25901  9Z18A7D1T8EUH58D  CGDGXAW6GNU6JIEG      Fiftieth Art'S  2016-05-08
# 25902  R0LUW64V2F3O2HSD  CGDGXAW6GNU6JIEG      Fiftieth Art'S  2017-02-16
# 25903  UMHMBM5M179IHX6D  CGDGXAW6GNU6JIEG      Fiftieth Art'S  2017-07-28
#
#         Val  Sale          Sales Rep      Sales Rep Id
# ...

# %% [markdown]
# - Chamando o método size, nós teremos o número de linhas de cada grupo

# %%
grouped.size()
# Out:
# Sales Rep
# Aaron Hendrickson    292
# Adam Sawyer          324
# Adele Kimmel         115
# Adrian Daugherty     369
# Adrianna Shelton      37
#                     ...
# Willie Lin            44
# Willie Rau            95
# Willie Sanchez       309
# Yvonne Jones          74
# Yvonne Lindsey        67
# Length: 499, dtype: int64

# %% [markdown]
# - Vamos verificar agora o número de pessoas levando em consideração apenas o primeiro nome

# %%
df.groupby(df['Sales Rep'].str.split(' ').str[0]).size()
# Out:
# Sales Rep
# Aaron        292
# Adam         324
# Adele        115
# Adrian       369
# Adrianna      37
#             ...
# Wesley       144
# Wilbert      213
# William     1393
# Willie       448
# Yvonne       141
# Length: 318, dtype: int64

# %% [markdown]
# - Podemos observar que existem vários registros "Williams". Vamos então agrupar todas as vendas feitas por alguem cujo o primeiro nome seja William

# %%
df.groupby(
    df['Sales Rep'].apply(lambda x: 'William' in x)
    ).size()
# Out:
# Sales Rep
# False    97111
# True      2889
# dtype: int64

# %% [markdown]
# - No seguinte exemplo, nós vamos usar *pd.Grouper(key=[COLUMN], freq=[FREQUENCY])* para agrupar nossos dados baseados numa frequencia específica. No nosso caso, a frequência é o ano ('Y') e a coluna é o 'Date'.

# %%
df = df.astype({'Date':'datetime64[ns]'})

df.groupby(
  pd.Grouper(
    key='Date',
    freq='Y'
  )
).size()
# Out:
# /tmp/ipykernel_932691/1798413105.py:4: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   pd.Grouper(
# Date
# 2014-12-31    19956
# 2015-12-31    20054
# 2016-12-31    20133
# 2017-12-31    20079
# 2018-12-31    19778
# Freq: YE-DEC, dtype: int64

# %% [markdown]
# - Além de 'Y', podemos usar frequências como dia ('D'), semana ('W'), mês ('M'), e quarter ('Q'). Mais frequencias podem ser conferidas na [documentação](http://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases)

# %%
df.groupby(
  pd.Grouper(
    key='Date',
    freq='Q'
  )
).size()
# Out:
# /tmp/ipykernel_932691/39869226.py:2: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   pd.Grouper(
# Date
# 2014-03-31    4949
# 2014-06-30    4948
# 2014-09-30    4986
# 2014-12-31    5073
# 2015-03-31    4958
# 2015-06-30    4968
# 2015-09-30    5109
# 2015-12-31    5019
# 2016-03-31    5064
# 2016-06-30    4892
# 2016-09-30    5148
# 2016-12-31    5029
# 2017-03-31    4959
# 2017-06-30    5102
# 2017-09-30    5077
# 2017-12-31    4941
# 2018-03-31    4889
# 2018-06-30    4939
# 2018-09-30    4975
# 2018-12-31    4975
# Freq: QE-DEC, dtype: int64

# %% [markdown]
# - Podemos chegar no mesmo resultado utilizando o método resample. Mas para isso, é necessário torna a coluna datetime como index

# %%
df.set_index('Date',inplace=True)

# %%
df.resample("Q").size()
# Out:
# /tmp/ipykernel_932691/276209721.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.resample("Q").size()
# Date
# 2014-03-31    4949
# 2014-06-30    4948
# 2014-09-30    4986
# 2014-12-31    5073
# 2015-03-31    4958
# 2015-06-30    4968
# 2015-09-30    5109
# 2015-12-31    5019
# 2016-03-31    5064
# 2016-06-30    4892
# 2016-09-30    5148
# 2016-12-31    5029
# 2017-03-31    4959
# 2017-06-30    5102
# 2017-09-30    5077
# 2017-12-31    4941
# 2018-03-31    4889
# 2018-06-30    4939
# 2018-09-30    4975
# 2018-12-31    4975
# Freq: QE-DEC, dtype: int64

# %% [markdown]
# - Os exemplos a seguir agrupam respectivamente a média e o acumulado de vendas por ano

# %%
df['Val'].resample("Y").mean()
# Out:
# /tmp/ipykernel_932691/2125047620.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df['Val'].resample("Y").mean()
# Date
# 2014-12-31    5032.190519
# 2015-12-31    5072.536551
# 2016-12-31    5055.860627
# 2017-12-31    5077.831765
# 2018-12-31    5076.345535
# Freq: YE-DEC, Name: Val, dtype: float64

# %%
df['Val'].resample("Y").sum()
# Out:
# /tmp/ipykernel_932691/2884217280.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df['Val'].resample("Y").sum()
# Date
# 2014-12-31    100422394
# 2015-12-31    101724648
# 2016-12-31    101789642
# 2017-12-31    101957784
# 2018-12-31    100399962
# Freq: YE-DEC, Name: Val, dtype: int64

# %% [markdown]
# - Vamos carregar um outro dataset

# %%
df = pd.DataFrame({'key1': ['a','a','b','b','a'],
                   'key2': ['one','two','one','two','one'],
                   'data1': np.random.randn(5),
                   'data2': np.random.randn(5)})

df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.028746  0.565779
# 1    a  two -0.023507  0.878761
# 2    b  one -0.015443  1.314137
# 3    b  two  0.537585 -0.418230
# 4    a  one -0.144199  1.274960

# %% [markdown]
# - Suponha que quiséssemos calcular a média da coluna data1 usando os rótulos de key1

# %%
grouped = df['data1'].groupby(df['key1'])
grouped

# %% [markdown]
# - grouped é um objeto GroupBy
# - A ideia é que esse objeto tenha todas as informações necessárias para então aplicar alguma operação em cada um dos grupos

# %% [markdown]
# - Para calcular as médias dos grupos, podemos chamar o método mean

# %%
grouped.mean()
# Out:
# key1
# a   -0.046320
# b    0.261071
# Name: data1, dtype: float64

# %% [markdown]
# - Observe que os dados (uma Series) foram agregados de acordo com a chave de grupo, gerando uma nova Series, que agora está indexado pelos valores únicos da coluna key1

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()
means
# Out:
# key1  key2
# a     one    -0.057726
#       two    -0.023507
# b     one    -0.015443
#       two     0.537585
# Name: data1, dtype: float64

# %% [markdown]
# - Nesse caso, agrupamos os dados usando duas chaves, e a Series resultante agora tem um índice hierárquico constituído dos pares de chave únicos observados

# %%
means.unstack()
# Out:
# key2       one       two
# key1
# a    -0.057726 -0.023507
# b    -0.015443  0.537585

# %% [markdown]
# - É possível passar os nomes das colunas como as chaves de grupo

# %%
df.groupby('key1').mean(numeric_only=True)
# Out:
#          data1     data2
# key1
# a    -0.046320  0.906500
# b     0.261071  0.447953

# %%
df.groupby(['key1', 'key2']).mean(numeric_only=True)
# Out:
#               data1     data2
# key1 key2
# a    one  -0.057726  0.920370
#      two  -0.023507  0.878761
# b    one  -0.015443  1.314137
#      two   0.537585 -0.418230

# %% [markdown]
# - Perceba que no primeiro caso, não há nenhuma coluna key2. Ela foi excluída do resultado.

# %% [markdown]
# - Outro método útil é size, que devolve uma Series contendo os tamanhos dos grupos

# %%
df.groupby(['key1','key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %% [markdown]
# ### Iterando por grupos

# %% [markdown]
# - O objeto GroupBy aceita iteração, gerando uma sequência de tuplas de 2 contendo o nome do grupo, junto com a porção de dados

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.028746  0.565779
# 1    a  two -0.023507  0.878761
# 2    b  one -0.015443  1.314137
# 3    b  two  0.537585 -0.418230
# 4    a  one -0.144199  1.274960

# %%
for name, group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one  0.028746  0.565779
# 1    a  two -0.023507  0.878761
# 4    a  one -0.144199  1.274960
# b
#   key1 key2     data1     data2
# 2    b  one -0.015443  1.314137
# 3    b  two  0.537585 -0.418230

# %%
for (k1,k2), group in df.groupby(['key1','key2']):
    print((k1,k2))
    print(group)
# Out:
# ('a', 'one')
#   key1 key2     data1     data2
# 0    a  one  0.028746  0.565779
# 4    a  one -0.144199  1.274960
# ('a', 'two')
#   key1 key2     data1     data2
# 1    a  two -0.023507  0.878761
# ('b', 'one')
#   key1 key2     data1     data2
# 2    b  one -0.015443  1.314137
# ('b', 'two')
#   key1 key2     data1    data2
# 3    b  two  0.537585 -0.41823

# %% [markdown]
# - Outra forma de iterar por um objeto GroupBy é utilizando sua função __iter__ e __next__

# %%
generator = df.groupby(['key1']).__iter__()

# %%
group_id, grouped_data = generator.__next__()
print(group_id) 
grouped_data
# Out:
# ('a',)
#   key1 key2     data1     data2
# 0    a  one  0.028746  0.565779
# 1    a  two -0.023507  0.878761
# 4    a  one -0.144199  1.274960

# %%
group_id, grouped_data = generator.__next__()
print(group_id) 
grouped_data
# Out:
# ('b',)
#   key1 key2     data1     data2
# 2    b  one -0.015443  1.314137
# 3    b  two  0.537585 -0.418230

# %% [markdown]
# - Pode ser útil gerar um dicionário de porções de dados usando um só linha de código

# %%
pieces = dict(list(df.groupby('key1')))
pieces
# Out:
# {'a':   key1 key2     data1     data2
#  0    a  one  0.028746  0.565779
#  1    a  two -0.023507  0.878761
#  4    a  one -0.144199  1.274960,
#  'b':   key1 key2     data1     data2
#  2    b  one -0.015443  1.314137
#  3    b  two  0.537585 -0.418230}

# %%
pieces['b']
# Out:
#   key1 key2     data1     data2
# 2    b  one -0.015443  1.314137
# 3    b  two  0.537585 -0.418230

# %% [markdown]
# ### Selecionando uma coluna ou um subconjunto de colunas

# %% [markdown]
# - Retornando uma Series

# %%
df.groupby(['key1', 'key2'])['data1'].mean()
# Out:
# key1  key2
# a     one    -0.057726
#       two    -0.023507
# b     one    -0.015443
#       two     0.537585
# Name: data1, dtype: float64

# %% [markdown]
# - Retornando um DataFrame

# %%
df.groupby(['key1', 'key2'])[['data1']].mean()
# Out:
#               data1
# key1 key2
# a    one  -0.057726
#      two  -0.023507
# b    one  -0.015443
#      two   0.537585

# %% [markdown]
# ### Agrupando com dicionários e Series

# %%
people = pd.DataFrame(np.random.randn(5,5),
                      columns=['a','b','c','d','e'], 
                      index=['Joe','Steve','Wes','Jim','Mike'])
people
# Out:
#               a         b         c         d         e
# Joe   -0.642654  2.597277 -0.538854 -0.411947  0.840606
# Steve  0.951108  1.764227 -0.287198 -1.262732 -0.738527
# Wes    1.243654 -0.409442 -0.984097  1.173229  0.042943
# Jim    0.577482  1.247581  1.391121 -0.824593  1.279897
# Mike   0.293267  0.398687  1.226326 -0.689714  0.067757

# %%
people.iloc[2:3, [1,2]] = np.nan
people
# Out:
#               a         b         c         d         e
# Joe   -0.642654  2.597277 -0.538854 -0.411947  0.840606
# Steve  0.951108  1.764227 -0.287198 -1.262732 -0.738527
# Wes    1.243654       NaN       NaN  1.173229  0.042943
# Jim    0.577482  1.247581  1.391121 -0.824593  1.279897
# Mike   0.293267  0.398687  1.226326 -0.689714  0.067757

# %%
mapping = {'a': 'red', 'b':'red', 'c':'blue', 'd':'blue', 'e':'red', 'f':'orange'}

# %%
people.groupby(mapping,axis=1).sum()
# Out:
# /tmp/ipykernel_932691/1313810169.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   people.groupby(mapping,axis=1).sum()
#            blue       red
# Joe   -0.950802  2.795228
# Steve -1.549930  1.976808
# Wes    1.173229  1.286598
# Jim    0.566528  3.104961
# Mike   0.536612  0.759712

# %% [markdown]
# - Note que construímos um array a partir de um dicionário que foi passado no groupby

# %% [markdown]
# - A mesma funcionalidade vale para Series, que pode ser vista como um mapeamento de tamanho fixo

# %%
map_series = pd.Series(mapping)
map_series
# Out:
# a       red
# b       red
# c      blue
# d      blue
# e       red
# f    orange
# dtype: object

# %%
people.groupby(map_series, axis=1).count()
# Out:
# /tmp/ipykernel_932691/1833935060.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   people.groupby(map_series, axis=1).count()
#        blue  red
# Joe       2    3
# Steve     2    3
# Wes       1    2
# Jim       2    3
# Mike      2    3

# %% [markdown]
# ### Agrupando com funções

# %% [markdown]
# - Suponha que quiséssemos agrupar pelo tamanho dos nomes das pessoas (índices do dataframe), basta usar a função len

# %%
people
# Out:
#               a         b         c         d         e
# Joe   -0.642654  2.597277 -0.538854 -0.411947  0.840606
# Steve  0.951108  1.764227 -0.287198 -1.262732 -0.738527
# Wes    1.243654       NaN       NaN  1.173229  0.042943
# Jim    0.577482  1.247581  1.391121 -0.824593  1.279897
# Mike   0.293267  0.398687  1.226326 -0.689714  0.067757

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3  1.178483  3.844858  0.852267 -0.063311  2.163446
# 4  0.293267  0.398687  1.226326 -0.689714  0.067757
# 5  0.951108  1.764227 -0.287198 -1.262732 -0.738527

# %% [markdown]
# ### Agregação de dados

# %% [markdown]
# - Métodos otimizados de groupby

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.028746  0.565779
# 1    a  two -0.023507  0.878761
# 2    b  one -0.015443  1.314137
# 3    b  two  0.537585 -0.418230
# 4    a  one -0.144199  1.274960

# %%
df.groupby(['key1']).count()
# Out:
#       key2  data1  data2
# key1
# a        3      3      3
# b        2      2      2

# %%
df.groupby(['key1']).sum()
# Out:
#            key2     data1     data2
# key1
# a     onetwoone -0.138959  2.719501
# b        onetwo  0.522142  0.895907

# %%
df.groupby(['key1']).mean(numeric_only=True)
# Out:
#          data1     data2
# key1
# a    -0.046320  0.906500
# b     0.261071  0.447953

# %%
df.groupby(['key1']).median(numeric_only=True)
# Out:
#          data1     data2
# key1
# a    -0.023507  0.878761
# b     0.261071  0.447953

# %%
df.groupby(['key1']).std(numeric_only=True)
# Out:
#          data1     data2
# key1
# a     0.088701  0.355403
# b     0.391050  1.224969

# %%
df.groupby(['key1']).min()
# Out:
#      key2     data1     data2
# key1
# a     one -0.144199  0.565779
# b     one -0.015443 -0.418230

# %%
df.groupby(['key1']).max()
# Out:
#      key2     data1     data2
# key1
# a     two  0.028746  1.274960
# b     two  0.537585  1.314137

# %%
df.groupby(['key1']).prod(numeric_only=True)
# Out:
#          data1     data2
# key1
# a     0.000097  0.633891
# b    -0.008302 -0.549612

# %%
df.groupby(['key1']).first(numeric_only=True)
# Out:
#          data1     data2
# key1
# a     0.028746  0.565779
# b    -0.015443  1.314137

# %%
df.groupby(['key1']).last(numeric_only=True)
# Out:
#          data1    data2
# key1
# a    -0.144199  1.27496
# b     0.537585 -0.41823

# %% [markdown]
# - É possível também definir as agregações a serem feitas. Por exemplo, é possível quantis de amostragem em uma Séries ou em colunas de DataFrame.

# %%
grouped = df.groupby('key1')
grouped['data1'].quantile(0.9)
# Out:
# key1
# a    0.018296
# b    0.482282
# Name: data1, dtype: float64

# %% [markdown]
# - Para usar suas próprias funções de agregação, passe qualquer função que agregue um array para o método aggregate ou agg

# %%
def peak_to_peak(arr):
    return arr.max() - arr.min()

# %%
grouped[['data1', 'data2']].agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     0.172945  0.709181
# b     0.553028  1.732368

# %% [markdown]
# ### Aplicação de função nas colunas e aplicação de várias funções

# %% [markdown]
# - Vamos voltar a usar os dados do IBGE

# %%
dados = pd.read_csv("datasets/dados.csv")
dados
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0      11     0     23    8              12    800  1.603808
# 1      11     1     23    2              12   1150  1.739790
# 2      11     1     35    8              15    880  1.760444
# 3      11     0     46    2               6   3500  1.783158
# 4      11     1     47    8               9    150  1.690631
# ...    ..   ...    ...  ...             ...    ...       ...
# 76835  53     1     46    2              11    812  1.687030
# 76836  53     0     30    4               7   1500  1.792934
# 76837  53     0     32    8              12   1300  1.830587
# 76838  53     0     57    8               4   1500  1.726344
# 76839  53     0     38    8               4    900  1.658305
#
# [76840 rows x 7 columns]

# %% [markdown]
# - Acrescentar legenda para as colunas Sexo e Cor

# %%
def get_cor(x):
    cor = {0:"Indígena", 2:"Branca", 4:"Preta", 6:"Amarela", 8:"Parda", 9:"Sem declaração"}
    return cor[x]

# %%
dados['Gênero'] = dados['Sexo'].apply(lambda x: "Feminino" if x else "Masculino")
dados['Cor2'] = dados['Cor'].apply(get_cor)

# %%
dados
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura     Gênero  \
# 0      11     0     23    8              12    800  1.603808  Masculino
# 1      11     1     23    2              12   1150  1.739790   Feminino
# 2      11     1     35    8              15    880  1.760444   Feminino
# 3      11     0     46    2               6   3500  1.783158  Masculino
# 4      11     1     47    8               9    150  1.690631   Feminino
# ...    ..   ...    ...  ...             ...    ...       ...        ...
# 76835  53     1     46    2              11    812  1.687030   Feminino
# 76836  53     0     30    4               7   1500  1.792934  Masculino
# 76837  53     0     32    8              12   1300  1.830587  Masculino
# 76838  53     0     57    8               4   1500  1.726344  Masculino
# 76839  53     0     38    8               4    900  1.658305  Masculino
#
#          Cor2
# 0       Parda
# 1      Branca
# 2       Parda
# 3      Branca
# 4       Parda
# ...

# %% [markdown]
# - Agrupando pelas colunas que acabamos de acrescentar

# %%
grouped = dados.groupby(['Gênero','Cor2'])

# %% [markdown]
# - Retornando quantos grupos foram gerados

# %%
grouped.ngroups
# Out:
# 10

# %% [markdown]
# - Observe que, para estatísticas descritivas, podemos passar o nome da função como uma string

# %%
grouped_renda = grouped['Renda']
grouped_renda.agg('mean')
# Out:
# Gênero     Cor2
# Feminino   Amarela     3027.341880
#            Branca      2109.866750
#            Indígena    2464.386139
#            Parda       1176.758516
#            Preta       1134.596400
# Masculino  Amarela     4758.251064
#            Branca      2925.744435
#            Indígena    1081.710938
#            Parda       1659.577425
#            Preta       1603.861687
# Name: Renda, dtype: float64

# %% [markdown]
# - Podemos passar uma lista de funções também

# %%
grouped_renda.agg(['mean','std',peak_to_peak])
# Out:
#                            mean           std  peak_to_peak
# Gênero    Cor2
# Feminino  Amarela   3027.341880   3731.173660         20000
#           Branca    2109.866750   3251.013154        100000
#           Indígena  2464.386139  11957.498292        120000
#           Parda     1176.758516   1596.233048         30000
#           Preta     1134.596400   1349.799809         23000
# Masculino Amarela   4758.251064   5740.824820         50000
#           Branca    2925.744435   4750.791872        200000
#           Indígena  1081.710938   1204.093490         10000
#           Parda     1659.577425   2312.087184        100000
#           Preta     1603.861687   1936.309271         50000

# %% [markdown]
# - É possível alterar o nome das funções que são exibidas no DataFrame

# %%
grouped_renda.agg([('Média','mean'),('Desvio Padrão',np.std)])
# Out:
# /tmp/ipykernel_932691/82146925.py:1: FutureWarning: The provided callable <function std at 0x7b2f39f6a660> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   grouped_renda.agg([('Média','mean'),('Desvio Padrão',np.std)])
#                           Média  Desvio Padrão
# Gênero    Cor2
# Feminino  Amarela   3027.341880    3731.173660
#           Branca    2109.866750    3251.013154
#           Indígena  2464.386139   11957.498292
#           Parda     1176.758516    1596.233048
#           Preta     1134.596400    1349.799809
# Masculino Amarela   4758.251064    5740.824820
#           Branca    2925.744435    4750.791872
#           Indígena  1081.710938    1204.093490
#           Parda     1659.577425    2312.087184
#           Preta     1603.861687    1936.309271

# %% [markdown]
# - Ordenar por uma coluna

# %%
grouped_renda.agg([('Média','mean'),('Desvio Padrão',np.std)]).sort_values(by="Média")
# Out:
# /tmp/ipykernel_932691/2526122811.py:1: FutureWarning: The provided callable <function std at 0x7b2f39f6a660> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   grouped_renda.agg([('Média','mean'),('Desvio Padrão',np.std)]).sort_values(by="Média")
#                           Média  Desvio Padrão
# Gênero    Cor2
# Masculino Indígena  1081.710938    1204.093490
# Feminino  Preta     1134.596400    1349.799809
#           Parda     1176.758516    1596.233048
# Masculino Preta     1603.861687    1936.309271
#           Parda     1659.577425    2312.087184
# Feminino  Branca    2109.866750    3251.013154
#           Indígena  2464.386139   11957.498292
# Masculino Branca    2925.744435    4750.791872
# Feminino  Amarela   3027.341880    3731.173660
# Masculino Amarela   4758.251064    5740.824820

# %% [markdown]
# - Filtrando pelos n maiores e menores valores de cada grupo

# %%
dados.groupby(['Gênero'])["Renda"].nlargest(2)
# Out:
# Gênero
# Feminino   43694    120000
#            40934    100000
# Masculino  28110    200000
#            43693    200000
# Name: Renda, dtype: int64

# %%
dados.groupby(['Gênero'])["Renda"].nsmallest(2)
# Out:
# Gênero
# Feminino   287    0
#            618    0
# Masculino  42     0
#            68     0
# Name: Renda, dtype: int64

# %% [markdown]
# - Retornando o n-ésimo valor do dataset

# %%
dados.groupby(['Gênero']).nth(3) #Retornando o terceiro valor de cada grupo
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura     Gênero   Cor2
# 5  11     1     34    8              12    790  1.637906   Feminino  Parda
# 9  11     0     26    8              12   1150  1.793203  Masculino  Parda

# %% [markdown]
# - Podemos especificar uma lista de funções a serem aplicadas em todas as colunas

# %%
functions = ['count', 'mean', 'max']

# %%
result = grouped[['Renda', 'Anos de Estudo']].agg(functions)
result
# Out:
#                     Renda                      Anos de Estudo
#                     count         mean     max          count       mean max
# Gênero    Cor2
# Feminino  Amarela     117  3027.341880   20000            117  12.495726  16
#           Branca     9621  2109.866750  100000           9621  11.297578  17
#           Indígena    101  2464.386139  120000            101   9.108911  17
#           Parda     10862  1176.758516   30000          10862   9.520714  17
#           Preta      2889  1134.596400   23000           2889   9.522326  17
# Masculino Amarela     235  4758.251064   50000            235  12.587234  16
#           Branca    22194  2925.744435  200000          22194  10.140353  17
#           Indígena    256  1081.710938   10000            256   7.875000  17
#           Parda     25063  1659.577425  100000          25063   8.329929  17
#           Preta      5502  1603.861687   50000           5502   8.514540  17

# %%
result['Renda']
# Out:
#                     count         mean     max
# Gênero    Cor2
# Feminino  Amarela     117  3027.341880   20000
#           Branca     9621  2109.866750  100000
#           Indígena    101  2464.386139  120000
#           Parda     10862  1176.758516   30000
#           Preta      2889  1134.596400   23000
# Masculino Amarela     235  4758.251064   50000
#           Branca    22194  2925.744435  200000
#           Indígena    256  1081.710938   10000
#           Parda     25063  1659.577425  100000
#           Preta      5502  1603.861687   50000

# %% [markdown]
# - Passando uma lista de tuplas personalizando o nome das funções

# %%
ftuples = [('Média', 'mean'),('Desvio Padrão', 'std')]

# %%
grouped[['Renda', 'Anos de Estudo']].agg(ftuples)
# Out:
#                           Renda               Anos de Estudo
#                           Média Desvio Padrão          Média Desvio Padrão
# Gênero    Cor2
# Feminino  Amarela   3027.341880   3731.173660      12.495726      4.205136
#           Branca    2109.866750   3251.013154      11.297578      4.245372
#           Indígena  2464.386139  11957.498292       9.108911      4.745316
#           Parda     1176.758516   1596.233048       9.520714      4.435326
#           Preta     1134.596400   1349.799809       9.522326      4.344210
# Masculino Amarela   4758.251064   5740.824820      12.587234      3.953232
#           Branca    2925.744435   4750.791872      10.140353      4.449924
#           Indígena  1081.710938   1204.093490       7.875000      4.408548
#           Parda     1659.577425   2312.087184       8.329929      4.460839
#           Preta     1603.861687   1936.309271       8.514540      4.417132

# %% [markdown]
# ### Devolvendo dados agregados sem índices de linha

# %% [markdown]
# - Podemos desativar o comportamento dos dados agregados serem retornados como índices passando as_index=False para groupby

# %%
dados.groupby(['Gênero', 'Renda'], as_index=False).mean(numeric_only=True)
# Out:
#          Gênero   Renda         UF  Sexo      Idade       Cor  Anos de Estudo  \
# 0      Feminino       0  28.293153   1.0  55.505304  5.749277        5.288332
# 1      Feminino       8  22.000000   1.0  49.000000  4.000000        2.000000
# 2      Feminino      10  22.800000   1.0  62.000000  8.000000        4.600000
# 3      Feminino      12  25.000000   1.0  55.000000  4.000000        1.000000
# 4      Feminino      13  28.000000   1.0  55.000000  2.000000        1.000000
# ...         ...     ...        ...   ...        ...       ...             ...
# 2232  Masculino   60000  29.000000   0.0  56.750000  3.500000       14.500000
# 2233  Masculino   80000  35.750000   0.0  57.750000  2.000000       13.000000
# 2234  Masculino   90000  33.000000   0.0  58.000000  8.000000       16.000000
# 2235  Masculino  100000  36.500000   0.0  62.750000  3.500000       16.000000
# 2236  Masculino  200000  34.333333   0.0  57.333333  2.000000       14.666667
#
#         Altura
# 0     1.699083
# ...

# %% [markdown]
# ### Filtrando dados

# %% [markdown]
# - O método *filter*, como o nome sugere, não muda o dado, mas seleciona um subconjunto de dados. Para usuários vindo do SQL, pensem em *filter* como um condição HAVING.

# %% [markdown]
# - No exemplo a seguir vamos filtrar pelo grupo de UFs cujo a renda média é maior que 2000

# %%
dados.groupby('UF').filter(lambda x: x['Renda'].mean() > 2000)
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura     Gênero  \
# 31818  31     0     40    2              12   1600  1.615956  Masculino
# 31819  31     0     58    8               5    850  1.575406  Masculino
# 31820  31     0     36    8               3   1400  1.748594  Masculino
# 31821  31     0     21    8              11   1500  1.658259  Masculino
# 31822  31     0     28    2               9   1600  1.624518  Masculino
# ...    ..   ...    ...  ...             ...    ...       ...        ...
# 76835  53     1     46    2              11    812  1.687030   Feminino
# 76836  53     0     30    4               7   1500  1.792934  Masculino
# 76837  53     0     32    8              12   1300  1.830587  Masculino
# 76838  53     0     57    8               4   1500  1.726344  Masculino
# 76839  53     0     38    8               4    900  1.658305  Masculino
#
#          Cor2
# 31818  Branca
# 31819   Parda
# 31820   Parda
# 31821   Parda
# 31822  Branca
# ...

# %% [markdown]
# - Filtrar pelo grupo de Idades que só ocorrem em um estado

# %%
# A idade pode aparecer apenas uma UF, mas pode se repetir na mesma UF.
# Portando, faz primeiro uma especie de unique de idade por UF.
df_part = dados[['UF', 'Idade']].groupby(['UF', 'Idade']).count().reset_index()

# Depois filtra pelas idades que só aparecem uma vez
df_part.groupby('Idade').filter(lambda x: x['UF'].count() == 1)
# Out:
#       UF  Idade
# 129   12     95
# 130   13     13
# 521   21     97
# 1137  31     94
# 1138  32     14
# 1759  52     99

# %% [markdown]
# - Filtrar pela idade que mais aparece no dataset

# %%
dados[['UF', 'Idade']].groupby('Idade')['UF'].count().idxmax()
# Out:
# np.int64(40)
